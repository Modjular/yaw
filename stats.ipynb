8',
'-0.7000000000000001 0.2 271.8',
'-0.7000000000000001 0.2 271.8',
'-0.7000000000000001 0.2 271.8',
'-0.7000000000000001 0.2 271.8',
'-0.7000000000000001 0.2 271.8',
'-0.7000000000000001 0.2 271.8',
'-0.7000000000000001 0.2 271.8',
'-0.7000000000000001 0.2 271.8',
'-0.7000000000000001 0.2 270.5',
'-0.8 0.2 267.7',
'-0.8 0.30000000000000004 253.3',
'-0.8 0.4 244.8',
'-0.8 0.5 231.4',
'-0.8 0.4 242.8',
'-0.8 0.5 220.20000000000002',
'-0.4 0.7000000000000001 205.10000000000002',
'-0.1 0.7000000000000001 197.20000000000002',
'0.1 0.8 188.4',
'0.1 0.8 188.4',
'-0.7000000000000001 0.5 227.9',
'0.1 0.8 184.9',
'0.1 0.7000000000000001 184.8',
'0.1 0.7000000000000001 184.8',
'0.1 0.7000000000000001 184.8',
'0.1 0.7000000000000001 184.8',
'0.1 0.7000000000000001 184.8',
'0 0.7000000000000001 184.8',
'0 0.7000000000000001 184.8',
'0 0.7000000000000001 184.8',
'0 0.7000000000000001 184.8',
'0 0.7000000000000001 184.8',
'-0.5 0.7000000000000001 184.9',
'-0.5 0.7000000000000001 184.9',
'-0.5 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
'-0.6000000000000001 0.7000000000000001 184.9',
]

# %%
angles = []
for line in data:
    roll, pitch, yaw = line.split(' ')
    angles.append((float(roll), float(pitch), float(yaw)))

# %%
print(angles)
# Out:
# [(-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.30000000000000004, 5.300000000000001), (-0.4, -0.3000000
# ...

# %%
import matplotlib.pyplot as plt

with open('raw.txt') as f:
    log_data = f.readlines()

# Extracting the signal data from the logs
signal_data = []
for line in log_data:
    if line and not line.startswith('172.24.10.105'):
        signal_tuple = tuple(map(float, line.split(',')))
        signal_data.append(signal_tuple)

# Unzipping the signal data into three separate lists
x, y, z = zip(*signal_data)

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(x, label='X-axis')
plt.plot(y, label='Y-axis')
plt.plot(z, label='Z-axis')
plt.xlabel('Sample Index')
plt.ylabel('Signal Value')
plt.title('Signal Data from Logs')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def simple_moving_average(signal, window_size):
    return np.convolve(signal, np.ones(window_size) / window_size, mode='same')

angles = angles[100:150]

# Extract yaw, pitch, and roll
yaw = [angle[0] for angle in angles]
pitch = [angle[1] for angle in angles]
roll = [angle[2] for angle in angles]

# Create a time axis (assuming data points are evenly spaced in time)
time = list(range(len(angles)))

# Plot the data
plt.figure(figsize=(17, 6))
plt.plot(time, yaw, label='Yaw')
# plt.plot(time, pitch, label='Pitch')
# plt.plot(time, roll, label='Roll')
plt.plot(time, simple_moving_average(yaw, 16), label='Smoothed Yaw (window=16)')
plt.plot(time, simple_moving_average(yaw, 7), label='Smoothed Yaw (window=10)')
plt.plot(time, simple_moving_average(yaw, 3), label='Smoothed Yaw (window=3)')
plt.xlabel('Time')
plt.ylabel('Angle (degrees)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import numpy as np

# Example data (replace with your actual data)
timestamps = pd.date_range('2023-01-01', periods=100, freq='100L')
data = pd.Series(np.random.randn(100).cumsum(), index=timestamps)

# Apply moving average filter with a window size of 5
smoothed_data = data.rolling(window=5).mean()

# Plot the original and smoothed data for comparison
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(data, label='Original Data')
plt.plot(smoothed_data, label='Smoothed Data', linewidth=2)
plt.legend()
plt.show()
# Out:
# /var/folders/_v/gqq9s6qn3m5_s22tf706wzcm0000gn/T/ipykernel_73482/2465731655.py:5: FutureWarning: 'L' is deprecated and will be removed in a future version, please use 'ms' instead.
#   timestamps = pd.date_range('2023-01-01', periods=100, freq='100L')
